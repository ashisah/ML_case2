# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import pandas as pd

# Function to generate new data points (for demonstration purposes)
features_raw_csv = pd.read_csv('set1.csv', delimiter = ',')
features_raw_csv['SEQUENCE_DTTM'] = pd.to_datetime(features_raw_csv['SEQUENCE_DTTM'], format='%H:%M:%S')
features_raw_csv['time_string'] = features_raw_csv['SEQUENCE_DTTM'].dt.strftime('%H:%M:%S')

unique_times = np.unique(features_raw_csv['SEQUENCE_DTTM'])

plt.xlim(np.min(features_raw_csv['LON'])+0.05, np.max(features_raw_csv['LON'])-0.05)
plt.ylim(np.min(features_raw_csv['LAT'])+0.05, np.max(features_raw_csv['LAT'])-0.05)

def add_data(frame): 
    xlist = []
    ylist = []
    time = unique_times[frame*2]
    result_df = features_raw_csv.loc[features_raw_csv['SEQUENCE_DTTM']<=time]
    for i in range(0, len(result_df)):
            xlist.append(result_df.iloc[i]['LON'])
            ylist.append(result_df.iloc[i]['LAT'])
        
    return xlist, ylist

# Initial data
x_data, y_data = add_data(0)

# Create initial scatter plot
fig, ax = plt.subplots()

scat = ax.scatter(x_data, y_data)

# Function to update the data of the scatter plot
def update(frame):
    new_x, new_y = add_data(frame)
    scat.set_offsets(np.c_[new_x, new_y])

# Create the animation
ani = animation.FuncAnimation(fig, update, frames=len(unique_times), interval=0.5)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import pandas as pd

frame_offset = 700 #7 ships
# Function to generate new data points (for demonstration purposes)
features_raw_csv = pd.read_csv('set3noVID.csv', delimiter = ',')
features_raw_csv['SEQUENCE_DTTM'] = pd.to_datetime(features_raw_csv['SEQUENCE_DTTM'], format='%H:%M:%S')
features_raw_csv['time_string'] = features_raw_csv['SEQUENCE_DTTM'].dt.strftime('%H:%M:%S')

unique_times = np.unique(features_raw_csv['SEQUENCE_DTTM'])

plt.xlim(-76.35, -75.05)
plt.ylim(36.90, 37.05)

def add_data(frame): 
    xlist = []
    ylist = []
    time = unique_times[frame+frame_offset]
    result_df = features_raw_csv.loc[features_raw_csv['SEQUENCE_DTTM']<=time]
    for i in range(0, len(result_df)):
            xlist.append(result_df.iloc[i]['LON'])
            ylist.append(result_df.iloc[i]['LAT'])
        
    return xlist, ylist

# Initial data
x_data, y_data = add_data(0)

# Create initial scatter plot
fig, ax = plt.subplots()

scat = ax.scatter(x_data, y_data)

frame_text = ax.text(0.02, 0.95, '', transform=ax.transAxes)

# Function to update the data of the scatter plot
def update(frame):
    new_x, new_y = add_data(frame)
    scat.set_offsets(np.c_[new_x, new_y])
    frame_text.set_text('Frame: {}'.format(frame+frame_offset))


# Create the animation
ani = animation.FuncAnimation(fig, update, frames=len(unique_times)-frame_offset, interval=0.01)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
# %matplotlib notebook
import matplotlib.pyplot as plt
import matplotlib.animation as animation
import numpy as np
import pandas as pd

frame_offset = 700 #7 ships
# Function to generate new data points (for demonstration purposes)
features_raw_csv = pd.read_csv('set3noVID.csv', delimiter = ',')
features_raw_csv['SEQUENCE_DTTM'] = pd.to_datetime(features_raw_csv['SEQUENCE_DTTM'], format='%H:%M:%S')
features_raw_csv['time_string'] = features_raw_csv['SEQUENCE_DTTM'].dt.strftime('%H:%M:%S')

unique_times = np.unique(features_raw_csv['SEQUENCE_DTTM'])

def add_data(frame): 
    xlist = []
    ylist = []
    time = unique_times[frame+frame_offset]
    result_df = features_raw_csv.loc[features_raw_csv['SEQUENCE_DTTM']<=time]
    for i in range(0, len(result_df)):
            xlist.append(result_df.iloc[i]['LON'])
            ylist.append(result_df.iloc[i]['LAT'])
        
    return xlist, ylist

# Initial data
x_data, y_data = add_data(0)

# Create initial scatter plot
fig, ax = plt.subplots()

scat = ax.scatter(x_data, y_data)
ax.xlim(-76.05, -75.95)
ax.ylim(36.94, 36.98)

frame_text = ax.text(0.02, 0.95, '', transform=ax.transAxes)

# Function to update the data of the scatter plot
def update(frame):
    new_x, new_y = add_data(frame)
    scat.set_offsets(np.c_[new_x, new_y])
    frame_text.set_text('Frame: {}'.format(frame+frame_offset))


# Create the animation
ani = animation.FuncAnimation(fig, update, frames=len(unique_times)-frame_offset, interval=0.05)

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[11], line 33
#      30 fig, ax = plt.subplots()
#      32 scat = ax.scatter(x_data, y_data)
# ---> 33 ax.xlim(-76.05, -75.95)
#      34 ax.ylim(36.94, 36.98)
#      36 frame_text = ax.text(0.02, 0.95, '', transform=ax.transAxes)
#
# AttributeError: 'Axes' object has no attribute 'xlim'
